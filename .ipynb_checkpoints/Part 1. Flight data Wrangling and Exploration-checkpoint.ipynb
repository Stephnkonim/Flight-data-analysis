# %% [markdown]
# # Part I - (Flight Data Exploration)
# ## by Nkonim Stephenie
#
# ## Introduction
# > The data we will be working with consist of flight arrival and departure records from January 2008 to April 2008 for every commercial flight in the US. There are over 2 million records of these flights
#
#
# ## Preliminary Wrangling

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# suppress warnings from final output
import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# > Loading dataset and describing its properties through the questions below.

# %%
#loading data
Flight_data = pd.read_csv('2008.csv')
Flight_data.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   1343.0        1325   1451.0
# 1  2008      1           3          4   1125.0        1120   1247.0
# 2  2008      1           3          4   2009.0        2015   2136.0
# 3  2008      1           3          4    903.0         855   1203.0
# 4  2008      1           3          4   1423.0        1400   1726.0
#
#    CRSArrTime UniqueCarrier  FlightNum        ...         TaxiIn  TaxiOut  \
# 0        1435            WN        588        ...            4.0      9.0
# 1        1245            WN       1343        ...            3.0      8.0
# 2        2140            WN       3841        ...            2.0     14.0
# 3        1205            WN          3        ...            5.0      7.0
# 4        1710            WN         25        ...            6.0     10.0
#
#    Cancelled  CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# 0          0               NaN         0          16.0          0.0      0.0
# 1          0               NaN         0           NaN          NaN      NaN
# 2          0               NaN         0           NaN          NaN      NaN
# 3          0               NaN         0           NaN          NaN      NaN
# 4          0               NaN         0          16.0          0.0      0.0
#
#    SecurityDelay  LateAircraftDelay
# 0            0.0                0.0
# 1            NaN                NaN
# 2            NaN                NaN
# 3            NaN                NaN
# 4            0.0                0.0
#
# [5 rows x 29 columns]

# %%
#to display all the columns in the dataset.
pd.set_option('display.max_columns',None)
Flight_data.head(10)
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   1343.0        1325   1451.0
# 1  2008      1           3          4   1125.0        1120   1247.0
# 2  2008      1           3          4   2009.0        2015   2136.0
# 3  2008      1           3          4    903.0         855   1203.0
# 4  2008      1           3          4   1423.0        1400   1726.0
# 5  2008      1           3          4   2024.0        2020   2325.0
# 6  2008      1           3          4   1753.0        1745   2053.0
# 7  2008      1           3          4    622.0         620    935.0
# 8  2008      1           3          4   1944.0        1945   2210.0
# 9  2008      1           3          4   1453.0        1425   1716.0
#
#    CRSArrTime UniqueCarrier  FlightNum TailNum  ActualElapsedTime  \
# 0        1435            WN        588  N240WN               68.0
# 1        1245            WN       1343  N523SW               82.0
# 2        2140            WN       3841  N280WN               87.0
# 3        1205            WN          3  N308SA              120.0
# 4        1710            WN         25  N462WN              123.0
# 5        2325            WN         51  N483WN              121.0
# 6        2050            WN        940  N493WN              120.0
# 7         930            WN       2621  N266WN              133.0
# 8        2215            WN        389  N266WN              146.0
# 9        1650            WN        519  N514SW              143.0
#
#    CRSElapsedTime  AirTime  ArrDelay  DepDelay Origin Dest  Distance  TaxiIn  \
# 0            70.0     55.0      16.0      18.0    HOU  LIT       393     4.0
# 1            85.0     71.0       2.0       5.0    HOU  MAF       441     3.0
# 2            85.0     71.0      -4.0      -6.0    HOU  MAF       441     2.0
# 3           130.0    108.0      -2.0       8.0    HOU  MCO       848     5.0
# 4           130.0    107.0      16.0      23.0    HOU  MCO       848     6.0
# 5           125.0    101.0       0.0       4.0    HOU  MCO       848    13.0
# 6           125.0    107.0       3.0       8.0    HOU  MCO       848     6.0
# 7           130.0    107.0       5.0       2.0    HOU  MCO       848     7.0
# 8           150.0    124.0      -5.0      -1.0    HOU  MDW       937     7.0
# 9           145.0    124.0      26.0      28.0    HOU  MDW       937     6.0
#
#    TaxiOut  Cancelled CancellationCode  Diverted  CarrierDelay  WeatherDelay  \
# 0      9.0          0              NaN         0          16.0           0.0
# 1      8.0          0              NaN         0           NaN           NaN
# 2     14.0          0              NaN         0           NaN           NaN
# 3      7.0          0              NaN         0           NaN           NaN
# 4     10.0          0              NaN         0          16.0           0.0
# 5      7.0          0              NaN         0           NaN           NaN
# 6      7.0          0              NaN         0           NaN           NaN
# 7     19.0          0              NaN         0           NaN           NaN
# 8     15.0          0              NaN         0           NaN           NaN
# 9     13.0          0              NaN         0          11.0           0.0
#
#    NASDelay  SecurityDelay  LateAircraftDelay
# 0       0.0            0.0                0.0
# 1       NaN            NaN                NaN
# 2       NaN            NaN                NaN
# 3       NaN            NaN                NaN
# 4       0.0            0.0                0.0
# 5       NaN            NaN                NaN
# 6       NaN            NaN                NaN
# 7       NaN            NaN                NaN
# 8       NaN            NaN                NaN
# 9       0.0            0.0               15.0

# %%
print(Flight_data.shape)
print(Flight_data.dtypes)
# Out:
# (2389217, 29)
# Year                   int64
# Month                  int64
# DayofMonth             int64
# DayOfWeek              int64
# DepTime              float64
# CRSDepTime             int64
# ArrTime              float64
# CRSArrTime             int64
# UniqueCarrier         object
# FlightNum              int64
# TailNum               object
# ActualElapsedTime    float64
# CRSElapsedTime       float64
# AirTime              float64
# ArrDelay             float64
# DepDelay             float64
# Origin                object
# Dest                  object
# Distance               int64
# TaxiIn               float64
# TaxiOut              float64
# Cancelled              int64
# CancellationCode      object
# Diverted               int64
# CarrierDelay         float64
# WeatherDelay         float64
# NASDelay             float64
# SecurityDelay        float64
# LateAircraftDelay    float64
# dtype: object

# %%
Flight_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2389217 entries, 0 to 2389216
# Data columns (total 29 columns):
# Year                 int64
# Month                int64
# DayofMonth           int64
# DayOfWeek            int64
# DepTime              float64
# CRSDepTime           int64
# ArrTime              float64
# CRSArrTime           int64
# UniqueCarrier        object
# FlightNum            int64
# TailNum              object
# ActualElapsedTime    float64
# CRSElapsedTime       float64
# AirTime              float64
# ArrDelay             float64
# DepDelay             float64
# Origin               object
# Dest                 object
# Distance             int64
# TaxiIn               float64
# TaxiOut              float64
# Cancelled            int64
# CancellationCode     object
# Diverted             int64
# CarrierDelay         float64
# WeatherDelay         float64
# NASDelay             float64
# SecurityDelay        float64
# LateAircraftDelay    float64
# dtypes: float64(14), int64(10), object(5)
# memory usage: 528.6+ MB

# %%
Flight_data.describe()
# Out:
#             Year         Month    DayofMonth     DayOfWeek       DepTime  \
# count  2389217.0  2.389217e+06  2.389217e+06  2.389217e+06  2.324775e+06
# mean      2008.0  2.505009e+00  1.566386e+01  3.909625e+00  1.340018e+03
# std          0.0  1.121493e+00  8.750405e+00  1.980431e+00  4.802717e+02
# min       2008.0  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%       2008.0  1.000000e+00  8.000000e+00  2.000000e+00  9.300000e+02
# 50%       2008.0  3.000000e+00  1.600000e+01  4.000000e+00  1.330000e+03
# 75%       2008.0  4.000000e+00  2.300000e+01  6.000000e+00  1.733000e+03
# max       2008.0  4.000000e+00  3.100000e+01  7.000000e+00  2.400000e+03
#
#          CRSDepTime       ArrTime    CRSArrTime     FlightNum  \
# count  2.389217e+06  2.319121e+06  2.389217e+06  2.389217e+06
# mean   1.329992e+03  1.485835e+03  1.496744e+03  2.213888e+03
# std    4.657833e+02  5.081295e+02  4.845238e+02  1.951392e+03
# min    0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    9.270000e+02  1.110000e+03  1.115000e+03  6.050000e+02
# 50%    1.325000e+03  1.516000e+03  1.520000e+03  1.544000e+03
# 75%    1.720000e+03  1.914000e+03  1.910000e+03  3.631000e+03
# max    2.359000e+03  2.400000e+03  2.400000e+03  9.741000e+03
#
#        ActualElapsedTime  CRSElapsedTime       AirTime      ArrDelay  \
# count       2.319121e+06    2.388810e+06  2.319121e+06  2.319121e+06
# mean        1.286189e+02    1.293776e+02  1.051016e+02  1.027357e+01
# std         7.025303e+01    6.948246e+01  6.766801e+01  3.963429e+01
# min         1.400000e+01   -2.500000e+01  0.000000e+00 -9.100000e+01
# 25%         7.800000e+01    8.000000e+01  5.600000e+01 -9.000000e+00
# 50%         1.110000e+02    1.110000e+02  8.700000e+01  0.000000e+00
# 75%         1.600000e+02    1.600000e+02  1.340000e+02  1.500000e+01
# max         9.050000e+02    1.435000e+03  8.860000e+02  2.461000e+03
#
#            DepDelay      Distance        TaxiIn       TaxiOut     Cancelled  \
# count  2.324775e+06  2.389217e+06  2.319121e+06  2.324775e+06  2.389217e+06
# mean   1.143636e+01  7.261589e+02  6.839862e+00  1.668584e+01  2.697202e-02
# std    3.653229e+01  5.571763e+02  4.846435e+00  1.102905e+01  1.620017e-01
# min   -9.200000e+01  1.700000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%   -4.000000e+00  3.250000e+02  4.000000e+00  1.000000e+01  0.000000e+00
# 50%    0.000000e+00  5.830000e+02  6.000000e+00  1.400000e+01  0.000000e+00
# 75%    1.100000e+01  9.570000e+02  8.000000e+00  1.900000e+01  0.000000e+00
# max    2.467000e+03  4.962000e+03  2.130000e+02  3.830000e+02  1.000000e+00
#
#            Diverted   CarrierDelay   WeatherDelay       NASDelay  \
# count  2.389217e+06  584583.000000  584583.000000  584583.000000
# mean   2.366466e-03      15.752957       2.938243      16.158462
# std    4.858875e-02      40.035487      19.166662      30.534167
# min    0.000000e+00       0.000000       0.000000       0.000000
# 25%    0.000000e+00       0.000000       0.000000       0.000000
# 50%    0.000000e+00       0.000000       0.000000       5.000000
# 75%    0.000000e+00      16.000000       0.000000      20.000000
# max    1.000000e+00    2436.000000    1148.000000    1357.000000
#
#        SecurityDelay  LateAircraftDelay
# count  584583.000000      584583.000000
# mean        0.080459          20.976710
# std         1.742579          38.617154
# min         0.000000           0.000000
# 25%         0.000000           0.000000
# 50%         0.000000           0.000000
# 75%         0.000000          27.000000
# max       392.000000        1254.000000

# %% [markdown]
# ### What is the structure of your dataset?
#
# > There are 2,389,217 flight records in the data set with 29 fcolumns.However some of these features are not relevant to the insight we are interested in and thus will be dropped to make the dataset more manageable.
#
#
# ### What is/are the main feature(s) of interest in your dataset?
#
# > I am most interested in figuring out the factors that are most likely to lead to flight delays(arrival and departure time) and possible cancellation and the day of the week delays are most likely to occur.
#
# ### What features in the dataset do you think will help support your investigation into your feature(s) of interest?
#
# > Some of the features in the dataset i think will help in my investigation are the delay features (carrier, security,weather,lateaircraft,NAS), Distance this trips covered and the time period(DayOfWeek and Month),cancellationcode for flights that were cancelled and date.

# %% [markdown]
# ### Data cleaning

# %%
#Making a copy of our data set.
Flight_data_copy= Flight_data.copy()

# %%
# Dropping unecessary columns
Flight_data_copy= Flight_data_copy.drop(['TaxiIn','TaxiOut','Diverted'], axis = 1)

# %% [markdown]
# ## Univariate Exploration
#
# > In this section, I will investigate distributions of individual variable to give us insight into how they affect flight schedules individually.
#
# Firstly I'll look at cancelled flights and the factor that is most likely to cause a trip to be cancelled.
#
# CancellationCode. <br>
# A = Carrier <br>
# B = weather <br>
# C = NAS <br>
# D = Security

# %%
#Flight_data_sample['CancellationCode'].unique()

# %% [markdown]
# #### We need to get data for just flights that were cancelled

# %%
#To get just data for just flights that were cancelled.
Cancelled_flights = Flight_data.loc[Flight_data['CancellationCode'].isin(['A','B','C','D'])]
Cancelled_flights.head(5)
# Out:
#      Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 42   2008      1           3          4      NaN         800      NaN
# 259  2008      1           3          4      NaN         700      NaN
# 454  2008      1           3          4      NaN        1100      NaN
# 480  2008      1           3          4      NaN         905      NaN
# 482  2008      1           3          4      NaN        1620      NaN
#
#      CRSArrTime UniqueCarrier  FlightNum TailNum  ActualElapsedTime  \
# 42          850            WN        609     NaN                NaN
# 259         830            WN        126     NaN                NaN
# 454        1215            WN       1146     NaN                NaN
# 480        1025            WN        469     NaN                NaN
# 482        1740            WN        618     NaN                NaN
#
#      CRSElapsedTime  AirTime  ArrDelay  DepDelay Origin Dest  Distance  \
# 42             50.0      NaN       NaN       NaN    HOU  SAT       192
# 259            90.0      NaN       NaN       NaN    LAS  OAK       407
# 454            75.0      NaN       NaN       NaN    LAX  OAK       337
# 480            80.0      NaN       NaN       NaN    LAX  SFO       337
# 482            80.0      NaN       NaN       NaN    LAX  SFO       337
#
#      TaxiIn  TaxiOut  Cancelled CancellationCode  Diverted  CarrierDelay  \
# 42      NaN      NaN          1                A         0           NaN
# 259     NaN      NaN          1                A         0           NaN
# 454     NaN      NaN          1                A         0           NaN
# 480     NaN      NaN          1                A         0           NaN
# 482     NaN      NaN          1                C         0           NaN
#
#      WeatherDelay  NASDelay  SecurityDelay  LateAircraftDelay
# 42            NaN       NaN            NaN                NaN
# 259           NaN       NaN            NaN                NaN
# 454           NaN       NaN            NaN                NaN
# 480           NaN       NaN            NaN                NaN
# 482           NaN       NaN            NaN                NaN

# %%
# using a barchart to show the distinct count of each code.
sb.countplot(data=Cancelled_flights, x='CancellationCode', color='darkred', order=['A','B','C','D']);
plt.title('Frequency of each cancellation cause')
plt.show();

# %%
#plotting a pie chart to further expand on our investigation
sorted_counts = Cancelled_flights['CancellationCode'].value_counts()
plt.pie(sorted_counts, labels = sorted_counts.index, startangle = 90, counterclock = False);
print(sorted_counts)
plt.title('Frequency of each cancellation cause')
plt.axis('square');
# Out:
# A    26075
# B    25744
# C    12617
# D        6
# Name: CancellationCode, dtype: int64

# %% [markdown]
# From the bar chart  and pie chart, it is clear that the most likely reason for a flight to be cancelled is the state of the carrier, the weather is next most likely factor.However for the first 4 months of 2008, security reasons have not affected flight cancellations in a significant way.

# %% [markdown]
# > Concerning Flights that were delayed. I'll like to look at features of these these flights to check for any significant information
#
# > I need to get data for delayed flights only. To do this I will first remove all data when the departure delay time is 0, and then drop all rows where any delay feature had a null value
#
# >Also all rows with departure delay time as negative values will also be dropped as negative values mean the flight was earlier than scheduled

# %% [markdown]
# #### We need to extract data for only delayed flights. however since we are interested in the features, we will also remove delayed flights that do not have values for any delay feature.

# %%
#changing all 0 values to Null 
columns = ['ArrDelay','DepDelay','CarrierDelay','WeatherDelay','NASDelay','SecurityDelay','LateAircraftDelay']

Flight_data[columns] = Flight_data[columns].replace(['None', 0], np.nan)

# %%
#Melting the 4 feature columns into just 2, Delfeature and Delfeature_value
Delayed_flight_data = pd.melt(Flight_data,id_vars=['Year','Month','DayofMonth','DayOfWeek','DepTime','CRSDepTime','ArrTime','CRSArrTime','UniqueCarrier',
                                                        'FlightNum','TailNum','ActualElapsedTime','CRSElapsedTime','AirTime','ArrDelay','DepDelay','Origin','Dest','Distance'], 
                              value_vars =['CarrierDelay','WeatherDelay','NASDelay','SecurityDelay','LateAircraftDelay'],
                              var_name = 'Delfeature' ,
                              value_name = 'Delfeature_time')

# %%
#Drop all records with Nan values in the Delfeature_value columns
Delayed_flights = Delayed_flight_data.dropna(subset=['Delfeature_time','DepDelay'] )
Delayed_flights.head(5)
# Out:
#     Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0   2008      1           3          4   1343.0        1325   1451.0
# 4   2008      1           3          4   1423.0        1400   1726.0
# 9   2008      1           3          4   1453.0        1425   1716.0
# 11  2008      1           3          4    708.0         615    936.0
# 12  2008      1           3          4   1749.0        1730   2039.0
#
#     CRSArrTime UniqueCarrier  FlightNum TailNum  ActualElapsedTime  \
# 0         1435            WN        588  N240WN               68.0
# 4         1710            WN         25  N462WN              123.0
# 9         1650            WN        519  N514SW              143.0
# 11         840            WN        969  N215WN              148.0
# 12        2000            WN       2174  N623SW              170.0
#
#     CRSElapsedTime  AirTime  ArrDelay  DepDelay Origin Dest  Distance  \
# 0             70.0     55.0      16.0      18.0    HOU  LIT       393
# 4            130.0    107.0      16.0      23.0    HOU  MCO       848
# 9            145.0    124.0      26.0      28.0    HOU  MDW       937
# 11           145.0    128.0      56.0      53.0    HOU  MDW       937
# 12           150.0    128.0      39.0      19.0    HOU  MDW       937
#
#       Delfeature  Delfeature_time
# 0   CarrierDelay             16.0
# 4   CarrierDelay             16.0
# 9   CarrierDelay             11.0
# 11  CarrierDelay             53.0
# 12  CarrierDelay             10.0

# %%
Delayed_flights.shape
# Out:
# (907638, 21)

# %%
Delayed_flights['DepDelay'].min()
# Out:
# -61.0

# %%
#to remove negative flight delay times
Delayed_flights=Delayed_flights.drop(Delayed_flights.index[Delayed_flights['DepDelay'] < 0])

# %%
Delayed_flights['DepDelay'].min()
# Out:
# 1.0

# %%
Delayed_flights.describe()
# Out:
#            Year          Month     DayofMonth      DayOfWeek        DepTime  \
# count  846371.0  846371.000000  846371.000000  846371.000000  846371.000000
# mean     2008.0       2.440468      15.130563       3.970714    1546.274471
# std         0.0       1.077577       9.021850       1.968951     451.420356
# min      2008.0       1.000000       1.000000       1.000000       1.000000
# 25%      2008.0       2.000000       7.000000       2.000000    1222.000000
# 50%      2008.0       2.000000      15.000000       4.000000    1608.000000
# 75%      2008.0       3.000000      23.000000       5.000000    1917.000000
# max      2008.0       4.000000      31.000000       7.000000    2400.000000
#
#           CRSDepTime        ArrTime     CRSArrTime      FlightNum  \
# count  846371.000000  846371.000000  846371.000000  846371.000000
# mean     1479.561686    1615.681485    1644.579944    2105.647449
# std       421.400057     574.632340     460.696735    1852.994702
# min         5.000000       1.000000       1.000000       1.000000
# 25%      1145.000000    1325.000000    1331.000000     607.000000
# 50%      1520.000000    1731.000000    1715.000000    1495.000000
# 75%      1825.000000    2043.000000    2019.000000    3360.000000
# max      2359.000000    2400.000000    2359.000000    9740.000000
#
#        ActualElapsedTime  CRSElapsedTime        AirTime       ArrDelay  \
# count      846371.000000   846371.000000  846371.000000  846371.000000
# mean          140.059041      133.285103     111.093761      61.274928
# std            72.560649       69.729824      69.082441      59.264967
# min            15.000000      -21.000000       0.000000      15.000000
# 25%            86.000000       80.000000      60.000000      25.000000
# 50%           124.000000      116.000000      93.000000      42.000000
# 75%           174.000000      165.000000     142.000000      76.000000
# max           905.000000      660.000000     886.000000    2461.000000
#
#             DepDelay       Distance  Delfeature_time
# count  846371.000000  846371.000000    846371.000000
# mean       54.500977     752.900088        36.144483
# std        58.516459     551.572050        47.988364
# min         1.000000      24.000000         1.000000
# 25%        20.000000     337.000000         9.000000
# 50%        37.000000     606.000000        20.000000
# 75%        69.000000     992.000000        43.000000
# max      2467.000000    4962.000000      2436.000000

# %%
Delayed_flights['DepDelay'].isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# #### Now that we have data for delayed flights with feature values. we can look at relationships between the features.

# %% [markdown]
# >To check the distribution of the departure delay time

# %%
#using as standard scaled plot
bins = np.arange(0,Delayed_flights['DepDelay'].max()+30,30)

plt.figure(figsize = [10,5])
plt.hist(data=Delayed_flights, x = 'DepDelay', bins = bins);
plt.xlabel('Departure delay time (mins)')
# Out:
# Text(0.5,0,'Departure delay time (mins)')

# %% [markdown]
# > The distribution is highly skewed, it follows an log normal distribution. I'll apply a logarithmic transform to the data so I can get a normal distribution

# %%
Delayed_flights['DepDelay'].describe()
# Out:
# count    846371.000000
# mean         54.500977
# std          58.516459
# min           1.000000
# 25%          20.000000
# 50%          37.000000
# 75%          69.000000
# max        2467.000000
# Name: DepDelay, dtype: float64

# %%
np.log(Delayed_flights['DepDelay'].describe())
# Out:
# count    13.648713
# mean      3.998219
# std       4.069308
# min       0.000000
# 25%       2.995732
# 50%       3.610918
# 75%       4.234107
# max       7.810758
# Name: DepDelay, dtype: float64

# %%
#logarithmic transformation plot
bins = 10** np.arange(0,8+0.25,0.25)
ticks = [1,5,10,20,30,45,60,100,200,300,450,600,1000,3000]
labels=['{}'.format(v) for v in ticks]

plt.figure(figsize = [12,6])
plt.hist(data=Delayed_flights ,x = 'DepDelay', bins = bins);
plt.xscale('log')
plt.xlabel('Departure delay time (mins)')
plt.xticks(ticks,labels,rotation=90);

# %% [markdown]
# Delay time has a lot of points  with low vlaues, with a very long tail od data pointa with large alues, with the logarithmic tranform. using a log-scale, the peak of our distribution is between 30  to 60, Also Delay times beyond 600 minutes (10hrs) are negligible and will be considered as outliers

# %%
Delayed_flights.query('DepDelay >=600')
# Out:
#           Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 109219    2008      1          22          2   1204.0         159   1531.0
# 115338    2008      1          22          2   2323.0        1230    224.0
# 127920    2008      1          31          4   1832.0         740   2057.0
# 168708    2008      1          31          4   1715.0         700   1954.0
# 204836    2008      1          23          3   1658.0         620   1737.0
# 211913    2008      1          28          1   2115.0        1100   2246.0
# 219140    2008      1           6          7   1158.0        2225   1857.0
# 219586    2008      1           6          7    729.0        1310   1054.0
# 255415    2008      1           2          3    850.0        2012   1113.0
# 321197    2008      1          30          3   1749.0         610   1945.0
# 326961    2008      1          24          4   1620.0         600   1825.0
# 327980    2008      1          22          2   2155.0        1120     32.0
# 332802    2008      1           5          6   1723.0         600   1922.0
# 335090    2008      1          18          5   1855.0         600   2110.0
# 335491    2008      1          29          2   1808.0         615   2010.0
# 335770    2008      1           4          5   1840.0         720   2149.0
# 335846    2008      1          23          3   1703.0         635   1941.0
# 336828    2008      1          25          5    408.0        1240    558.0
# 338259    2008      1          31          4   1824.0         600   2034.0
# 342071    2008      1          21          1   1650.0         600   1908.0
# 374993    2008      1          11          5   2140.0         835    139.0
# 384134    2008      1          19          6   1810.0         634   2003.0
# 395430    2008      1          12          6    722.0        1800    919.0
# 397063    2008      1          23          3   1758.0         715   1934.0
# 405084    2008      1          21          1   1729.0         720   1842.0
# 408140    2008      1           1          2    823.0        1815   1017.0
# 409616    2008      1           1          2   1817.0         715   2126.0
# 412647    2008      1           6          7   1853.0         630   1956.0
# 415854    2008      1           8          2   2357.0         900     31.0
# 422512    2008      1          31          4   2022.0         600     39.0
# ...        ...    ...         ...        ...      ...         ...      ...
# 11254301  2008      3          30          7    718.0        1720    903.0
# 11259574  2008      3          15          6   1116.0        1800   1455.0
# 11262476  2008      3           8          6   1256.0        1135   1627.0
# 11264256  2008      3          31          1    756.0        1500   1102.0
# 11264362  2008      3           8          6    726.0        1435    938.0
# 11264708  2008      3           8          6    942.0        1835   1034.0
# 11265214  2008      3          21          5    852.0        1530   1230.0
# 11265223  2008      3          30          7    852.0        1530   1255.0
# 11266673  2008      3          15          6   2213.0        1045    357.0
# 11727995  2008      4           4          5   1419.0        1644   1515.0
# 11728717  2008      4          27          7   2234.0        1130     26.0
# 11737359  2008      4          28          1    630.0        1825    756.0
# 11739560  2008      4          25          5    617.0        1750    835.0
# 11746337  2008      4          11          5   1553.0        1955   1801.0
# 11747912  2008      4          25          5    812.0        1800    916.0
# 11752125  2008      4          25          5   1106.0        1810   1118.0
# 11753357  2008      4          11          5   1310.0        1835   1453.0
# 11753371  2008      4          25          5   1021.0        1835   1159.0
# 11755427  2008      4          18          5   2043.0         900   2203.0
# 11756180  2008      4          10          4    759.0        2015    944.0
# 11758872  2008      4          18          5     33.0        1240    200.0
# 11761423  2008      4          13          7    601.0        1635    811.0
# 11770922  2008      4          16          3    711.0        1205   1240.0
# 11776332  2008      4          15          2    612.0        1250    853.0
# 11780565  2008      4          10          4    708.0        1700    934.0
# 11786961  2008      4           4          5    654.0        1633    851.0
# 11792252  2008      4          10          4    724.0        1417    858.0
# 11818641  2008      4           4          5   1312.0        2115   2120.0
# 11824087  2008      4          25          5    850.0        2100   1016.0
# 11838925  2008      4           2          3    558.0        1120   1125.0
#
#           CRSArrTime UniqueCarrier  FlightNum TailNum  ActualElapsedTime  \
# 109219           527            XE       2940  N16151              147.0
# 115338          1558            XE       2652  N14905              121.0
# 127920           930            XE       2554  N12922              145.0
# 168708           948            OH       5000  N784CA               99.0
# 204836           705            OO       5510  N291SW               39.0
# 211913          1215            OO       2531  N507CA              151.0
# 219140           515            UA         36  N664UA              299.0
# 219586          1653            UA         47  N664UA              325.0
# 255415          2234            UA       1595  N445UA              203.0
# 321197           748            DL       1010  N928DL              116.0
# 326961           819            EV       4285  N824AS               65.0
# 327980          1419            EV       4309  N981EV               97.0
# 332802           754            EV       4466  N930EV               59.0
# 335090           743            EV       4539  N914EV              135.0
# 335491           848            EV       4553  N900EV              122.0
# 335770          1032            EV       4562  N841AS              129.0
# 335846           907            EV       4563  N835AS              158.0
# 336828          1542            EV       4598  N717EV               50.0
# 338259           750            EV       4646  N975EV              130.0
# 342071           811            EV       4781  N935EV              138.0
# 374993          1205            HA         19  N596HA              359.0
# 384134           835            MQ       3238  N902AE              113.0
# 395430          2005            MQ       3722  N647AE              117.0
# 397063           900            MQ       3786  N679AE               96.0
# 405084           725            MQ       4104  N834AE              133.0
# 408140          1920            MQ       4218  N832AE              114.0
# 409616           715            MQ       4272  N931AE              249.0
# 412647           705            MQ       4382  N516AE              123.0
# 415854           950            MQ       4524  N908AE               34.0
# 422512           955            MQ       4912  N733KR              197.0
# ...              ...           ...        ...     ...                ...
# 11254301        1840            AA       1733  N586AA              165.0
# 11259574        2155            AA       1944  N5EAAA              219.0
# 11262476        1737            AA       2093  N3CDAA              211.0
# 11264256        1805            AA       2262  N5DVAA              126.0
# 11264362        1635            AA       2275  N545AA              132.0
# 11264708        1950            AA       2291  N628AA              112.0
# 11265214        1910            AA       2318  N5DJAA              158.0
# 11265223        1910            AA       2318  N616AA              183.0
# 11266673        1650            AA       2398  N5CBAA              224.0
# 11727995        1745            MQ       3342  N219AE               56.0
# 11728717        1320            MQ       3367  N939AE              172.0
# 11737359        1945            MQ       3724  N932AE               86.0
# 11739560        1935            MQ       3826  N685AE              198.0
# 11746337        2150            MQ       4096  N719AE               68.0
# 11747912        1905            MQ       4156  N909AE              124.0
# 11752125        1840            MQ       4322  N503AE               72.0
# 11753357        2015            MQ       4368  N664MS               43.0
# 11753371        2015            MQ       4368  N623AE               38.0
# 11755427         940            MQ       4455  N805AE               80.0
# 11756180        2135            MQ       4487  N506AE              105.0
# 11758872        1410            MQ       4651  N733KR               87.0
# 11761423        1840            MQ       4807  N849AE              130.0
# 11770922        1728            NW        398  N372NW              209.0
# 11776332        1526            NW        647  N501US              221.0
# 11780565        1918            NW        872  N785NC               86.0
# 11786961        1840            NW       1253   N9338              177.0
# 11792252        1605            NW       1699  N3324L              154.0
# 11818641         515            AA         14  N343AA              308.0
# 11824087        2220            AA        381  N610AA              146.0
# 11838925        1659            AA       1082  N517AA              207.0
#
#           CRSElapsedTime  AirTime  ArrDelay  DepDelay Origin Dest  Distance  \
# 109219             148.0    127.0     604.0     605.0    PHX  IAH      1009
# 115338             148.0     89.0     626.0     653.0    BNA  EWR       748
# 127920             110.0    101.0     687.0     652.0    BHM  IAH       562
# 168708             108.0     91.0     606.0     615.0    OMA  CVG       614
# 204836              45.0     25.0     632.0     638.0    SBA  LAX        89
# 211913             135.0    130.0     631.0     615.0    BDL  MKE       780
# 219140             290.0    276.0     822.0     813.0    OGG  SFO      2338
# 219586             343.0    301.0    1081.0    1099.0    LAX  OGG      2486
# 255415             202.0    174.0     759.0     758.0    FLL  ORD      1182
# 321197              98.0     86.0     717.0     699.0    SRQ  ATL       445
# 326961              79.0     50.0     606.0     620.0    EVV  ATL       350
# 327980             119.0     84.0     613.0     635.0    MLI  ATL       633
# 332802              54.0     36.0     688.0     683.0    DHN  ATL       171
# 335090             103.0     97.0     807.0     775.0    FWA  ATL       508
# 335491             153.0    105.0     682.0     713.0    ACY  ATL       678
# 335770             132.0    101.0     677.0     680.0    OMA  ATL       821
# 335846             152.0    131.0     634.0     628.0    SWF  ATL       784
# 336828             122.0     30.0     856.0     928.0    MKE  ATL       669
# 338259             110.0    107.0     764.0     744.0    CAK  ATL       528
# 342071             131.0    106.0     657.0     650.0    FNT  ATL       644
# 374993             330.0    334.0     814.0     785.0    SMF  HNL      2462
# 384134             121.0     88.0     688.0     696.0    LFT  DFW       351
# 395430             125.0     96.0     794.0     802.0    DSM  DFW       624
# 397063             105.0     78.0     634.0     643.0    GPT  DFW       500
# 405084              65.0     65.0     677.0     609.0    MQT  MKE       236
# 408140              65.0     47.0     897.0     848.0    CMI  ORD       135
# 409616              60.0     51.0     851.0     662.0    FWA  ORD       157
# 412647              95.0     60.0     771.0     743.0    CLE  ORD       316
# 415854              50.0     24.0     881.0     897.0    MSN  ORD       109
# 422512             175.0    133.0     884.0     862.0    XNA  LGA      1147
# ...                  ...      ...       ...       ...    ...  ...       ...
# 11254301           140.0    101.0     863.0     838.0    DCA  ORD       612
# 11259574           235.0    208.0    1020.0    1036.0    SJU  IAD      1571
# 11262476           362.0    177.0    1370.0    1521.0    LGA  MIA      1097
# 11264256           125.0     94.0    1017.0    1016.0    EGE  DFW       720
# 11264362           120.0    105.0    1023.0    1011.0    BNA  DFW       631
# 11264708           135.0     98.0     884.0     907.0    EGE  LAX       748
# 11265214           160.0    123.0    1040.0    1042.0    HDN  ORD      1009
# 11265223           160.0    120.0    1065.0    1042.0    HDN  ORD      1009
# 11266673           245.0    205.0     667.0     688.0    EGE  MIA      1811
# 11727995            61.0     37.0    1290.0    1295.0    GGG  DFW       140
# 11728717           170.0    147.0     666.0     664.0    CHS  DFW       987
# 11737359            80.0     64.0     731.0     725.0    CRP  DFW       354
# 11739560           165.0    145.0     780.0     747.0    CAE  DFW       922
# 11746337            55.0     40.0    1211.0    1198.0    MKE  MQT       236
# 11747912           125.0     94.0     851.0     852.0    SYR  ORD       607
# 11752125            90.0     55.0     998.0    1016.0    CMH  ORD       296
# 11753357            40.0     28.0    1118.0    1115.0    GRB  MQT       134
# 11753371            40.0     24.0     944.0     946.0    GRB  MQT       134
# 11755427            40.0     22.0     743.0     703.0    MKE  ORD        67
# 11756180            80.0     68.0     729.0     704.0    ORD  BNA       409
# 11758872            90.0     63.0     710.0     713.0    EWR  RDU       416
# 11761423           125.0     98.0     811.0     806.0    CVG  LGA       585
# 11770922           203.0    190.0    1152.0    1146.0    SMF  MSP      1518
# 11776332           216.0    188.0    1047.0    1042.0    RSW  MSP      1416
# 11780565            78.0     57.0     856.0     848.0    MSP  GRR       408
# 11786961           187.0    156.0     851.0     861.0    EWR  MEM       946
# 11792252           168.0    132.0    2453.0    2467.0    CLT  MSP       930
# 11818641           300.0    285.0     965.0     957.0    OGG  LAX      2486
# 11824087           140.0    111.0     716.0     710.0    LGA  ORD       733
# 11838925           219.0    181.0    1106.0    1118.0    LAS  ORD      1515
#
#                  Delfeature  Delfeature_time
# 109219         CarrierDelay            604.0
# 115338         CarrierDelay            626.0
# 127920         CarrierDelay            652.0
# 168708         CarrierDelay            606.0
# 204836         CarrierDelay            632.0
# 211913         CarrierDelay            631.0
# 219140         CarrierDelay             14.0
# 219586         CarrierDelay           1032.0
# 255415         CarrierDelay            555.0
# 321197         CarrierDelay            699.0
# 326961         CarrierDelay            606.0
# 327980         CarrierDelay            613.0
# 332802         CarrierDelay            683.0
# 335090         CarrierDelay            775.0
# 335491         CarrierDelay            682.0
# 335770         CarrierDelay            677.0
# 335846         CarrierDelay            628.0
# 336828         CarrierDelay            856.0
# 338259         CarrierDelay            744.0
# 342071         CarrierDelay            630.0
# 374993         CarrierDelay            785.0
# 384134         CarrierDelay            688.0
# 395430         CarrierDelay            781.0
# 397063         CarrierDelay            634.0
# 405084         CarrierDelay            609.0
# 408140         CarrierDelay            486.0
# 409616         CarrierDelay            662.0
# 412647         CarrierDelay            743.0
# 415854         CarrierDelay            858.0
# 422512         CarrierDelay            566.0
# ...                     ...              ...
# 11254301  LateAircraftDelay             25.0
# 11259574  LateAircraftDelay             20.0
# 11262476  LateAircraftDelay             31.0
# 11264256  LateAircraftDelay            232.0
# 11264362  LateAircraftDelay            273.0
# 11264708  LateAircraftDelay            323.0
# 11265214  LateAircraftDelay            195.0
# 11265223  LateAircraftDelay            138.0
# 11266673  LateAircraftDelay             68.0
# 11727995  LateAircraftDelay             22.0
# 11728717  LateAircraftDelay              1.0
# 11737359  LateAircraftDelay             12.0
# 11739560  LateAircraftDelay            138.0
# 11746337  LateAircraftDelay              4.0
# 11747912  LateAircraftDelay             45.0
# 11752125  LateAircraftDelay             24.0
# 11753357  LateAircraftDelay             88.0
# 11753371  LateAircraftDelay            309.0
# 11755427  LateAircraftDelay              5.0
# 11756180  LateAircraftDelay            130.0
# 11758872  LateAircraftDelay              3.0
# 11761423  LateAircraftDelay             28.0
# 11770922  LateAircraftDelay              7.0
# 11776332  LateAircraftDelay            163.0
# 11780565  LateAircraftDelay            257.0
# 11786961  LateAircraftDelay            129.0
# 11792252  LateAircraftDelay             17.0
# 11818641  LateAircraftDelay            342.0
# 11824087  LateAircraftDelay            158.0
# 11838925  LateAircraftDelay              2.0
#
# [660 rows x 21 columns]

# %% [markdown]
# > Now that we have the distribution of delay times, we'll look at the features that cause this delays and the relationships between them.

# %%
count=Delayed_flights['Delfeature'].value_counts()

# %%
count.sort_values(ascending=False).plot(kind='bar',color='red')
plt.xticks(rotation=90)
plt.title('Frequency of each delay feature occurence')
plt.show();

# %%
feature_counts = Delayed_flights['Delfeature'].value_counts()

plt.pie(feature_counts, startangle = 90,
       counterclock = False, wedgeprops = {'width' : 0.4})
plt.legend(feature_counts.index,  bbox_to_anchor = (1,0.5), loc = 6)
plt.title('Frequency of delay feature occurences')
plt.axis('square');

# %% [markdown]
# The features that has caused most of the delays in flights from our visualization are NAS delays. this include a variety of things such as airport operations, high airtraffic volume, non-risky weather conditions and air traffic control delays. Lateaircraft delays and carrier delays follow closely. however Extreme weather conditions and security do not seem to have  too significant an effect on flight delays

# %% [markdown]
# ### Discuss the distribution(s) of your variable(s) of interest. Were there any unusual points? Did you need to perform any transformations?
#
# > The Delay time variable had a long range of values and data points with large values, so I had to do a log transform, with the transformthe peak of our distribution is between 30  to 60, Also Delay times beyond 600 minutes (10hrs) are negligible and will be considered as outliers
#
# ### Of the features you investigated, were there any unusual distributions? Did you perform any operations on the data to tidy, adjust, or change the form of the data? If so, why did you do this?
#
# > In the course of my investingation, it was neccessary for me to create two other dataframe with information from the main dataset, one dataset for cancelled flights containing information for all flights that ended being cancelled. The other data set was for all delayed flights, I had to melt the columns of each delay feature and their values.
# > From the disribution of delay times, some outliers existed and had to be removed so as not to greatly affect out analysis

# %% [markdown]
# ## Bivariate Exploration
#
# > In this section,  I will be investigating relationships between pairs of variables in the data set. I will be using the extracted data for cancelled and delayed flights in the previous section.

# %%
Delayed_flights.describe()
# Out:
#            Year          Month     DayofMonth      DayOfWeek        DepTime  \
# count  846371.0  846371.000000  846371.000000  846371.000000  846371.000000
# mean     2008.0       2.440468      15.130563       3.970714    1546.274471
# std         0.0       1.077577       9.021850       1.968951     451.420356
# min      2008.0       1.000000       1.000000       1.000000       1.000000
# 25%      2008.0       2.000000       7.000000       2.000000    1222.000000
# 50%      2008.0       2.000000      15.000000       4.000000    1608.000000
# 75%      2008.0       3.000000      23.000000       5.000000    1917.000000
# max      2008.0       4.000000      31.000000       7.000000    2400.000000
#
#           CRSDepTime        ArrTime     CRSArrTime      FlightNum  \
# count  846371.000000  846371.000000  846371.000000  846371.000000
# mean     1479.561686    1615.681485    1644.579944    2105.647449
# std       421.400057     574.632340     460.696735    1852.994702
# min         5.000000       1.000000       1.000000       1.000000
# 25%      1145.000000    1325.000000    1331.000000     607.000000
# 50%      1520.000000    1731.000000    1715.000000    1495.000000
# 75%      1825.000000    2043.000000    2019.000000    3360.000000
# max      2359.000000    2400.000000    2359.000000    9740.000000
#
#        ActualElapsedTime  CRSElapsedTime        AirTime       ArrDelay  \
# count      846371.000000   846371.000000  846371.000000  846371.000000
# mean          140.059041      133.285103     111.093761      61.274928
# std            72.560649       69.729824      69.082441      59.264967
# min            15.000000      -21.000000       0.000000      15.000000
# 25%            86.000000       80.000000      60.000000      25.000000
# 50%           124.000000      116.000000      93.000000      42.000000
# 75%           174.000000      165.000000     142.000000      76.000000
# max           905.000000      660.000000     886.000000    2461.000000
#
#             DepDelay       Distance  Delfeature_time
# count  846371.000000  846371.000000    846371.000000
# mean       54.500977     752.900088        36.144483
# std        58.516459     551.572050        47.988364
# min         1.000000      24.000000         1.000000
# 25%        20.000000     337.000000         9.000000
# 50%        37.000000     606.000000        20.000000
# 75%        69.000000     992.000000        43.000000
# max      2467.000000    4962.000000      2436.000000

# %% [markdown]
# Firstly, I will considering the days of the week and their relatioship with departure delay times.<br>
# #### Code for each day.
# 1 = Monday,
# 2 = Tuesday,
# 3 = Wednesday,
# 4 = Thursday,
# 5 = Friday,
# 6 = Saturday,
# 7 = Sunday
#
# #### Code for each Month
# 1 = January
# 2 = February
# 3 = March
# 4 = April

# %%
Delayed_flights['DepDelay'].describe()
# Out:
# count    846371.000000
# mean         54.500977
# std          58.516459
# min           1.000000
# 25%          20.000000
# 50%          37.000000
# 75%          69.000000
# max        2467.000000
# Name: DepDelay, dtype: float64

# %%
bins = 10** np.arange(0,8+0.25,0.25)
ticks = [1,5,10,20,30,45,60,100,200,300,450,600,1000,3000]
labels=['{}'.format(v) for v in ticks]
g = sb.FacetGrid(data = Delayed_flights, col='DayOfWeek', col_wrap=3)
plt.xscale('log')
g.map(plt.hist, 'DepDelay', bins = bins)

# %% [markdown]
# The peak of our distribution is between 30  to 60 minutes,  however the height of this peak is different for each day of the week. the highest peak is on day 5 (a friday). nterestingly enough saturday has the the lowest peak of this waiting duration.

# %%
bins = 10** np.arange(0,8+0.25,0.25)
ticks = [1,5,10,20,30,45,60,100,200,300,450,600,1000,3000]
labels=['{}'.format(v) for v in ticks]
g = sb.FacetGrid(data = Delayed_flights, col='Month', col_wrap=3)
plt.xscale('log')
g.map(plt.hist, 'DepDelay', bins = bins)

# %% [markdown]
# Since the peak of our distribution is between 30  to 60 minutes, and the height of this peak is different for each month, we can tell Month 4 (April) has the the lowest peak of this waiting duration while february and march have the highest peaks

# %%
sb.countplot(data = Delayed_flights, x= 'Delfeature', hue = 'Month', palette = 'Blues')
plt.xticks(rotation=90);
plt.legend( bbox_to_anchor = (1,0.5), loc = 6)
plt.title('Count of each delay feature across the four month')
# Out:
# Text(0.5,1,'Count of each delay feature across the four month')

# %% [markdown]
# From the graph, we can tell that late aircraft delay has the highest count in all the months with the excption of april where NAS delay has the highest count

# %%
sb.barplot(data = Delayed_flights, x = 'Delfeature', y='Delfeature_time', color ='green')
plt.xticks(rotation=15);
plt.ylabel('Avg. delfeature_time')
plt.title('Average delay time caused by each delay feature')
# Out:
# Text(0.5,1,'Average delay time caused by each delay feature')

# %% [markdown]
# The highest average delay time was caused by weather delay and late aircraft with more than 40 minutes delay time. Carrier delay has an average time of between 30 to 40 minutes, NAS delay has an average delay time of between 20 to 30 minutes, and security delay has an average delay time of just  below 20 minutes.

# %%
sb.regplot(data = Delayed_flights, x = 'DayOfWeek', y ='DepDelay', truncate = False, x_jitter = 0.4, scatter_kws = {'alpha':1/20});
plt.scatter(data = Delayed_flights, x = 'DayOfWeek', y ='DepDelay', alpha = 1/20);
plt.title('Day of the week VS Departure delay time')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-769e6eec8181> in <module>()
# ----> 1 sb.regplot(data = Delayed_flights, x = 'DayOfWeek', y ='DepDelay', truncate = False, x_jitter = 0.4, scatter_kws = {'alpha':1/20});
#       2 plt.scatter(data = Delayed_flights, x = 'DayOfWeek', y ='DepDelay', alpha = 1/20);
#       3 plt.title('Day of the week Vs Departure delay time')
#
# NameError: name 'sb' is not defined

# %% [markdown]
# Checking for any relationships between Departure delay time and the days of the week. The strenght of the relationship is not very clear, however we can tell that the longest delay times occured on day 4 (Thursday) and Day 7 (sunday)

# %% [markdown]
# ##### I'll like to see the change over time of the number of cancelled flights during the first 4 months

# %%
Cancelled_flights.head()
# Out:
#      Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 42   2008      1           3          4      NaN         800      NaN
# 259  2008      1           3          4      NaN         700      NaN
# 454  2008      1           3          4      NaN        1100      NaN
# 480  2008      1           3          4      NaN         905      NaN
# 482  2008      1           3          4      NaN        1620      NaN
#
#      CRSArrTime UniqueCarrier  FlightNum TailNum  ActualElapsedTime  \
# 42          850            WN        609     NaN                NaN
# 259         830            WN        126     NaN                NaN
# 454        1215            WN       1146     NaN                NaN
# 480        1025            WN        469     NaN                NaN
# 482        1740            WN        618     NaN                NaN
#
#      CRSElapsedTime  AirTime  ArrDelay  DepDelay Origin Dest  Distance  \
# 42             50.0      NaN       NaN       NaN    HOU  SAT       192
# 259            90.0      NaN       NaN       NaN    LAS  OAK       407
# 454            75.0      NaN       NaN       NaN    LAX  OAK       337
# 480            80.0      NaN       NaN       NaN    LAX  SFO       337
# 482            80.0      NaN       NaN       NaN    LAX  SFO       337
#
#      TaxiIn  TaxiOut  Cancelled CancellationCode  Diverted  CarrierDelay  \
# 42      NaN      NaN          1                A         0           NaN
# 259     NaN      NaN          1                A         0           NaN
# 454     NaN      NaN          1                A         0           NaN
# 480     NaN      NaN          1                A         0           NaN
# 482     NaN      NaN          1                C         0           NaN
#
#      WeatherDelay  NASDelay  SecurityDelay  LateAircraftDelay
# 42            NaN       NaN            NaN                NaN
# 259           NaN       NaN            NaN                NaN
# 454           NaN       NaN            NaN                NaN
# 480           NaN       NaN            NaN                NaN
# 482           NaN       NaN            NaN                NaN

# %%
Cancelled_flights_with_date = Cancelled_flights.copy()

# %%
#Change data type of year, Month and day of the month to string. 
Cancelled_flights_with_date[['Year','Month','DayofMonth','DayOfWeek']] = Cancelled_flights_with_date[['Year','Month','DayofMonth','DayOfWeek']].astype(str)

#Change data type of year, Month and day of the month to string. 
Cancelled_flights_with_date['Date']=Cancelled_flights_with_date["Year"]+ '-' +Cancelled_flights_with_date['Month']

# %%
#convert the date column to date time
Cancelled_flights_with_date['Date']= pd.to_datetime(Cancelled_flights_with_date['Date'])

# %%
Cancelled_flights_with_date=Cancelled_flights_with_date[['Date','Cancelled']]

# %%
#grouping by count of delay time
C= Cancelled_flights_with_date.groupby('Date')['Cancelled'].count()

# %%
C. head()
# Out:
# Date
# 2008-01-01    17308
# 2008-02-01    20596
# 2008-03-01    16183
# 2008-04-01    10355
# Name: Cancelled, dtype: int64

# %%
plt.style.use("fivethirtyeight")
plt.figure(figsize=(12,10))
plt.xlabel("Date")
plt.ylabel('Number of cancelled flights')
plt.title("Cancelled fights over the first four months")
plt.xticks(rotation=90);
plt.ylim(1000,25000,1000)
plt.plot(C)

# %% [markdown]
# From the graph, over 15000 flights were cancelled in January, the numbers increased in february to over 20000 flights, it gradually reduces to between  15,000 and 10,000,  in april, the number of cancelled flights had dropped to just above 10,000 flights.

# %%
g = sb.FacetGrid(data = Cancelled_flights, col='DayOfWeek', col_wrap=3)
g.map(sb.countplot, 'CancellationCode');

# %% [markdown]
# Faceting the cancellation frequency by the days of the week suggests the likely reason a flight may be cancelled on s particular day. While Security reasons are the least likely reason as their occurence is negligible throughout the week. Weather conditions (cancellation code B) have the highest occurences on day 2(Tuesday), day 5 (Friday), Day 6 (saturdays). Carrier (Cancellation Code A) has its highest occcurences on day 1 (Monday), Day 3(Wednesday), Day 4(Thursday) and day 7(Sunday)

# %%
Cancellation_code = ['A', 'B', 'C', 'D']
codeclasses = pd.api.types.CategoricalDtype(ordered= True, categories = Cancellation_code)

Cancelled_flights['CancellationCode'] = Cancelled_flights['CancellationCode'].astype(codeclasses)

vplot= sb.violinplot(data = Cancelled_flights, x = 'CancellationCode', y= 'Distance');
plt.title('Cancellation Code vs flight Distance of cancelled flight');

# %%
sb.boxplot(data = Cancelled_flights, x = 'CancellationCode', y= 'Distance')
plt.ylim(vplot.get_ylim());
plt.title('Cancellation Code vs flight Distance of cancelled flight');

# %% [markdown]
# From the graphs, we can tell that the cancellation of flights with longer distance have been most affected by the state of carrier closely followed by Weather conditions. Our first plot looks as though the difference in this effect is large, however our box plot clearly shows that the difference is because of outliers and the difference is not that large. Security reasons on the other hand affect just short distance flights.

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. How did the feature(s) of interest vary with other features in the dataset?
# >For Delayed flights
#
# The peak of our distribution is between 30  to 60 minutes, and the height of this peak is different for each day depending on the number of flights delayed, highest peak is on day 5 (a friday). interestingly enough saturday has the the lowest peak of this waiting duration.
#
# In terms of fequency in occurence, we can tell that late aircraft delay has the highest count in all the months with the exception of april where NAS delay has the highest count
#
# Using average delay time of each Delay feature, The highest average delay time was caused by weather delay and late aircraft with more than 40 minutes delay time. Carrier delay has an average time of between 30 to 40 minutes, NAS delay has an average delay time of between 20 to 30 minutes, and security delay has an average delay time of just  below 20 minutes.
#
#  > For Cancelled flights
#
# Throught the first 4 month of the year, over 15000 flights were cancelled in January, over 20000 flights in february,between 15,000 and 10,000 in March and in April,just above 10,000 flights.
#
# Throughout the week. Weather conditions (cancellation code B) have the highest occurences on day 2(Tuesday), day 5 (Friday), Day 6 (saturdays). Carrier (Cancellation Code A) has its highest occcurences on day 1 (Monday), Day 3(Wednesday), Day 4(Thursday) and day 7(Sunday).
#
# In terms of flight distance affected by cancellation, we can tell that longer distance have been most affected by the state of carrier closely followed by Weather conditions. Security reasons on the other hand affect just short distance flights.
#
#
# ### Did you observe any interesting relationships between the other features (not the main feature(s) of interest)?
#
#  In the relationship between cancellation code and flight distance, Our first plot looks as though the difference in this effect is large, however our box plot clearly shows that the difference is because of outliers and the difference is not that large.
#
#  This influence of the outliers can also be noticeable with the relationshiph between the Day of the week and departure delay time,although the relationship is unclear, we can get an idea of which day the longest departure delay times occured.
#
#  Thirdly, it is interesting that the peak of our distribution has at its lowest number of flights  delay on day 6 (saturday). which is a weekend and therefore should have more traffic.

# %% [markdown]
# ## Multivariate Exploration
#
# > In This section i'll be exploring how each departure delay affect departue time in the first four months as well as the relationship between fliht distance during the week to cancellation code

# %%
Cancelled_flights.head()
# Out:
#      Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 42   2008      1           3          4      NaN         800      NaN
# 259  2008      1           3          4      NaN         700      NaN
# 454  2008      1           3          4      NaN        1100      NaN
# 480  2008      1           3          4      NaN         905      NaN
# 482  2008      1           3          4      NaN        1620      NaN
#
#      CRSArrTime UniqueCarrier  FlightNum TailNum  ActualElapsedTime  \
# 42          850            WN        609     NaN                NaN
# 259         830            WN        126     NaN                NaN
# 454        1215            WN       1146     NaN                NaN
# 480        1025            WN        469     NaN                NaN
# 482        1740            WN        618     NaN                NaN
#
#      CRSElapsedTime  AirTime  ArrDelay  DepDelay Origin Dest  Distance  \
# 42             50.0      NaN       NaN       NaN    HOU  SAT       192
# 259            90.0      NaN       NaN       NaN    LAS  OAK       407
# 454            75.0      NaN       NaN       NaN    LAX  OAK       337
# 480            80.0      NaN       NaN       NaN    LAX  SFO       337
# 482            80.0      NaN       NaN       NaN    LAX  SFO       337
#
#      TaxiIn  TaxiOut  Cancelled CancellationCode  Diverted  CarrierDelay  \
# 42      NaN      NaN          1                A         0           NaN
# 259     NaN      NaN          1                A         0           NaN
# 454     NaN      NaN          1                A         0           NaN
# 480     NaN      NaN          1                A         0           NaN
# 482     NaN      NaN          1                C         0           NaN
#
#      WeatherDelay  NASDelay  SecurityDelay  LateAircraftDelay
# 42            NaN       NaN            NaN                NaN
# 259           NaN       NaN            NaN                NaN
# 454           NaN       NaN            NaN                NaN
# 480           NaN       NaN            NaN                NaN
# 482           NaN       NaN            NaN                NaN

# %%
Cancelled_flights['CancellationCode'].unique()
# Out:
# [A, C, B, D]
# Categories (4, object): [A < B < C < D]

# %%
Cancel_marker= [['A','o'],
                ['B','s'],
                ['C','^'],
                ['D','X']]

for Cancel, marker in Cancel_marker:
    df_cancelled = Cancelled_flights[Cancelled_flights['CancellationCode']==Cancel]
    sb.regplot(data = df_cancelled, x = 'DayOfWeek', y = 'Distance', x_jitter = 0.4,fit_reg = False, marker=marker)
plt.legend(['A','B','C','D'],bbox_to_anchor = (1,0.5), loc = 6)
plt.legend( bbox_to_anchor = (1,0.5), loc = 6)

# %% [markdown]
# > With flights that were cancelled. we can tell that C(NAS) reasons seem to affect the cancellation of short distance flights more(1000 km or less) through the week.B(Weather) and A(Carrier) affect long distance flights with A (carrier) being the most common reason for the cancellatio of a long distance flight on days (2,3,5,6 and 7).

# %%
ax = sb.pointplot(data = Delayed_flights, x = 'Month', y= 'Delfeature_time', hue = 'Delfeature',
                  dodge = 0.3, linestyles = "")
plt.legend( bbox_to_anchor = (1,0.5), loc = 6)
plt.title('Effect of each delay feature by month')
# Out:
# Text(0.5,1,'Effect of each delay feature by month')

# %%
ax=sb.barplot(data =Delayed_flights, x = 'Month', y = 'Delfeature_time', hue = 'Delfeature')
ax.legend(loc = 8 , ncol = 3, framealpha =1, title = 'Delay Feature')
plt.legend( bbox_to_anchor = (1,0.5), loc = 6)
plt.title('Effect of each delay feature by month')
# Out:
# Text(0.5,1,'Effect of each delay feature by month')

# %% [markdown]
# > With the two graphs above  we are interested in looking at the effect of each delay feature by delay time across the four months. interestingly late aircraft has caused longer delay times in the first two months closely followed by weather conditions. However weather conditions cause longer delay times in the 3rd and 4th month followed by late aircraft. The other delay features are relatively consistent in terms of delay times , carrier delay (35 minutes),NAS delay (between 20 to 30 minutes), security(betwen 10 to 20 minutes)

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. Were there features that strengthened each other in terms of looking at your feature(s) of interest?
#
# >Cancelled flights
#
# In our Bivariate plot we found that A(carrier) had the highest effect on flight cancellation than any other cancellation code, Relating this with flight distance makes this conclusion more obvious as  code A (carrier) is  the most common reason for the cancellation of long distance flights on days (2,3,5,6 and 7).
#
# >Delayed flights
#
# Although I had NAS Delay as the most frequently occuring Delay feature, it is late aircraft delays that have caused longest delay times in the first two months closely followed by weather conditions. Carrier Delay also occur more often than weather, However weather conditions cause longer delay times in the 3rd and 4th month followed by late aircraft.

# %% [markdown]
# ### References

# %% [markdown]
# https://www.tutorialspoint.com/matplotlib-how-to-show-the-count-values-on-the-top-of-a-bar-in-a-countplot
#
# https://stackoverflow.com/questions/71254492/how-to-delete-any-row-for-which-a-corresponding-column-has-a-negative-value-usin
#
# https://pythonguides.com/matplotlib-time-series-plot/
#
# https://www.sheffield.com/2019/different-flight-delays.html
